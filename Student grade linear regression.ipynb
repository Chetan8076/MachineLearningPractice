# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('student-mat.csv',sep=";")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = df[df.columns[1:30]]
y = df[df.columns[30:33]]

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print(*df["Mjob"].unique())
# Out:
# at_home health other services teacher

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-3930ea67a7b1> in <module>
# ----> 1 lm.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
df1 = df.copy()

# %%
# df["GP"] = df["school"].apply(lambda x: 1 if x =="GP"  else 0)
# df["MS"] = df["school"].apply(lambda x: 1 if x =="MS"  else 0)
# df["MS"] = df["school"].apply(lambda x: 1 if x =="MS"  else 0)

# %%
def fillValues(parentCol):
    for i in df1[parentCol].unique():
        df1[i] = df1[parentCol].apply(lambda x: 1 if x == i else 0)

# %%
l = ["school","sex","address","famsize","Pstatus","Mjob","Fjob","reason","guardian"]

# %%
YesNoValues = ["schoolsup","famsup","paid","activities","nursery","higher","internet","romantic"]

# %%
for j in l:
    fillValues(j)

for j in YesNoValues:
    df1[j] = df1[j].apply(lambda x: 1 if x == "Yes" else 0)

# %%
df1.drop(l,axis = 1,inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr())

# %%
#spliting data on modified version of data that is df1
y = df1["G1"]
# p = ["G1","G2","G3"]

X =df1[[i for i in df1.columns if i!="G3" ] ]

# %%
y
# Out:
# 0       5
# 1       5
# 2       7
# 3      15
# 4       6
# 5      15
# 6      12
# 7       6
# 8      16
# 9      14
# 10     10
# 11     10
# 12     14
# 13     10
# 14     14
# 15     14
# 16     13
# 17      8
# 18      6
# 19      8
# 20     13
# 21     12
# 22     15
# 23     13
# 24     10
# 25      6
# 26     12
# 27     15
# 28     11
# 29     10
#        ..
# 365    10
# 366    13
# 367     7
# 368    11
# 369    14
# 370     7
# 371    14
# 372    13
# 373     6
# 374    19
# 375     8
# 376    15
# 377     8
# 378    15
# 379    10
# 380    15
# 381     7
# 382    11
# 383     6
# 384     6
# 385    10
# 386     6
# 387     7
# 388     7
# 389     6
# 390     9
# 391    14
# 392    10
# 393    11
# 394     8
# Name: G1, Length: 395, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.13, random_state=42)

# %%
X.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  schoolsup  famsup  paid  \
# 0   18     4     4           2          2         0          0       0     0
# 1   17     1     1           1          2         0          0       0     0
# 2   15     1     1           1          2         3          0       0     0
# 3   15     4     2           1          3         0          0       0     0
# 4   16     3     3           1          2         0          0       0     0
#
#    activities  ...  T  at_home  other  services  teacher  course  home  \
# 0           0  ...  0        0      0         0        1       1     0
# 1           0  ...  1        0      0         0        0       1     0
# 2           0  ...  1        0      0         0        0       0     0
# 3           0  ...  1        0      0         1        0       0     1
# 4           0  ...  1        0      0         0        0       0     1
#
#    reputation  mother  father
# 0           0       1       0
# ...

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Predictions = lm.predict(X_test)

# %%
plt.subplot(1,2,1)
plt.plot(Predictions)
plt.subplot(1,2,2)
plt.plot(y_test)

# %%
plt.scatter(y_test,Predictions)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,Predictions)
# Out:
# 5.149876688129841e-29

# %%
plt.figure(figsize=(10,10))
plt.plot(y_test - Predictions)

# %%
len(lm.coef_)
# Out:
# 42

# %%
lm.intercept_
# Out:
# -0.0005592666416927017

# %%
Predictions.mean()
# Out:
# 10.625954198473282

# %%
y_test.mean()
# Out:
# 10.625954198473282

# %%
X_test.head()
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  schoolsup  famsup  \
# 78    17     2     1           2          1         3          0       0
# 371   18     1     2           3          1         0          0       0
# 248   18     3     3           1          2         1          0       0
# 55    16     2     1           1          2         0          0       0
# 390   20     2     2           1          2         2          0       0
#
#      paid  activities  ...  T  at_home  other  services  teacher  course  \
# 78      0           0  ...  1        0      0         0        0       0
# 371     0           0  ...  1        0      0         1        0       0
# 248     0           0  ...  1        0      0         1        0       1
# 55      0           0  ...  0        0      0         0        0       0
# 390     0           0  ...  0        0      1         1        0       1
#
#      home  reputation  mother  father
# 78      1           0       1       0
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr())
